# %%
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import pickle as pkl
from utils import *

# %% [markdown]
# # LOOK AHEAD EXPLORATION SGD #

# %% [markdown]
# ## NO LOOK AHEAD VERSIONS ##

# %% [markdown]
# ## No Look Ahead RAlpha=100 Weight-LR=1e-1 ##

# %%
fname = 'm4m_cache/lookaheadExplore/sgd.nolookahead/results.pkl'
data = pkl.load(open(fname, 'rb'))
print('Results')
for k, v in data.items():
    v = np.array(v)
    print(k, v.mean(), v.std())
print('--'*60)
fname = 'm4m_cache/lookaheadExplore/sgd.nolookahead/meta_medium-sized_mammals/0/weight_stats.pkl'
vis_data = vis_file(fname, smooth_factor=10)


# print('--'*60)

fldrs = glob('m4m_cache/lookaheadExplore/sgd.nolookahead/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')
# Out:
# Results
# pre_ft.small_mammals 0.444 0.0
# pre_ft.medium-sized_mammals 0.462 0.0
# medium-sized_mammals 0.452 0.0
# ------------------------------------------------------------------------------------------------------------------------
# Folder Name :  m4m_cache/lookaheadExplore/sgd.nolookahead/meta_medium-sized_mammals/
# First 2/3 Stats :  [0.49437359 0.50562641]
# Last 1/3 Stats :  [0.50524738 0.49475262]
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## No Look Ahead RAlpha=500 Weight-LR=1.0 ##

# %%
fname = 'm4m_cache/lookaheadExplore/sgd.nolookahead.RAlpha=500.wlr=1.0/results.pkl'
data = pkl.load(open(fname, 'rb'))
print('Results')
for k, v in data.items():
    v = np.array(v)
    print(k, v.mean(), v.std())
print('--'*60)
fname = 'm4m_cache/lookaheadExplore/sgd.nolookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/0/weight_stats.pkl'
vis_data = vis_file(fname, smooth_factor=10)


# print('--'*60)

fldrs = glob('m4m_cache/lookaheadExplore/sgd.nolookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')
# Out:
# Results
# pre_ft.small_mammals 0.442 0.0
# pre_ft.medium-sized_mammals 0.448 0.0
# medium-sized_mammals 0.454 0.0
# ------------------------------------------------------------------------------------------------------------------------
# Folder Name :  m4m_cache/lookaheadExplore/sgd.nolookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/
# First 2/3 Stats :  [0.49812453 0.50187547]
# Last 1/3 Stats :  [0.50524738 0.49475262]
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## LOOK AHEAD VERSIONS ##

# %% [markdown]
# ## Look Ahead RAlpha=100 Weight-LR=1e-1 ##

# %%
fname = 'm4m_cache/lookaheadExplore/sgd.lookahead/results.pkl'
data = pkl.load(open(fname, 'rb'))
print('Results')
for k, v in data.items():
    v = np.array(v)
    print(k, v.mean(), v.std())
print('--'*60)
fname = 'm4m_cache/lookaheadExplore/sgd.lookahead/meta_medium-sized_mammals/0/weight_stats.pkl'
vis_data = vis_file(fname, smooth_factor=10)


# print('--'*60)

fldrs = glob('m4m_cache/lookaheadExplore/sgd.lookahead/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')
# Out:
# Results
# pre_ft.small_mammals 0.368 0.0
# pre_ft.medium-sized_mammals 0.432 0.0
# medium-sized_mammals 0.454 0.0
# ------------------------------------------------------------------------------------------------------------------------
# Folder Name :  m4m_cache/lookaheadExplore/sgd.lookahead/meta_medium-sized_mammals/
# First 2/3 Stats :  [0.47486872 0.52513128]
# Last 1/3 Stats :  [0.47376312 0.52623688]
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Look Ahead RAlpha=500 Weight-LR=1.0 ##

# %%
fname = 'm4m_cache/lookaheadExplore/sgd.lookahead.RAlpha=500.wlr=1.0/results.pkl'
data = pkl.load(open(fname, 'rb'))
print('Results')
for k, v in data.items():
    v = np.array(v)
    print(k, v.mean(), v.std())
print('--'*60)
fname = 'm4m_cache/lookaheadExplore/sgd.lookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/0/weight_stats.pkl'
vis_data = vis_file(fname, smooth_factor=10)


# print('--'*60)

fldrs = glob('m4m_cache/lookaheadExplore/sgd.lookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')
# Out:
# Results
# pre_ft.small_mammals 0.494 0.0
# pre_ft.medium-sized_mammals 0.48 0.0
# medium-sized_mammals 0.478 0.0
# ------------------------------------------------------------------------------------------------------------------------
# Folder Name :  m4m_cache/lookaheadExplore/sgd.lookahead.RAlpha=500.wlr=1.0/meta_medium-sized_mammals/
# First 2/3 Stats :  [0.49062266 0.50937734]
# Last 1/3 Stats :  [0.48725637 0.51274363]
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# large_lr = 'm4m_cache/tests/best_perf_sofar.grouped.valIsMeta/meta_medium-sized_mammals/0/weight_stats.pkl'
# vis_data = vis_file(large_lr, smooth_factor=10)

# # print('--'*60)

# fldrs = glob('m4m_cache/tests/best_perf_sofar.grouped.valIsMeta/meta_medium-sized_mammals/')
# display_fldr(fldrs[0], inner_key='0')
# loc = "m4m_cache/tests/best_perf_sofar.separated.valIsMeta/meta_medium-sized_mammals/0/metrics.pkl"
# stats = pkl.load(open(loc, 'rb'))
# print(vis_data.shape)
# sm = [v[0] for v in stats['small_mammals']['train']]
# mm = [v[0] for v in stats['medium-sized_mammals']['train']]
# sm_grads = vis_data[0, :, 3]
# mm_grads = vis_data[1, :, 3]

# fig, ax = plt.subplots(1, 2, figsize=(15, 10))
# ax[0].plot(sm, label='small_mammals loss')
# ax[0].plot(mm, label='medium-sized_mammals loss')
# ax[0].legend()

# ax[1].plot(sm_grads, label='small_mammals gradNorm')
# ax[1].plot(mm_grads, label='medium-sized_mammals gradNorm')
# ax[1].legend()
# plt.show()

# %% [markdown]
# # ALL EXPERIMENTS ARE WITH 5% TRAIN DATA AND ALL VALIDATION DATA #
#
# ## Primary Task = {Medium-sized Mammals}

# %% [markdown]
# ### NB [1] : All experiments labelled with Corruption  actually have fraction corrrupted = 0.0 - exactly same data as primary task ###
# ### NB [2] : All have tasks weigthings set to 0.5 throught training ###
# ### NB [3] : All have task dot products do not include the head ###

# %%
large_lr = 'm4m_cache/dp_tests/noheaddp.corrput_head_is_dphead.separateBN.small_lr/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/dp_tests/noheaddp.corrput_head_is_dphead.separateBN.small_lr/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %%
large_lr = 'm4m_cache/dp_tests/noheaddp.main_head_is_dphead.separateBN.small_lr/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/dp_tests/noheaddp.main_head_is_dphead.separateBN.small_lr/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %% [markdown]
# # Use medium-sized_mammals as dev head #

# %%
large_lr = 'm4m_cache/test/noheaddp.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/test/noheaddp.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %% [markdown]
# # Use corrupted-medium-sized_mammals as dev head #

# %%
large_lr = 'm4m_cache/test/noheaddp.devoncorruptedhead.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/test/noheaddp.devoncorruptedhead.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %% [markdown]
# # Use randomly initialized head as dev head #

# %%
# # for idx in range(3):
# #     large_lr = 'm4m_cache/test/noheaddp.dev_on_separate_devhead.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/{}/weight_stats.pkl'.format(idx)
# #     _ = vis_file(large_lr, smooth_factor=1)

#     print('--'*60)
fldrs = ['m4m_cache/test/noheaddp.dev_on_separate_devhead.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/']
display_fldr(fldrs[0], inner_key='*')

# %% [markdown]
# # Use randomly initialized head as dev head. Initialized corrupt_head, main_head to dev_head #

# %%
fldr = 'm4m_cache/test/noheaddp.corrhead_mainhead_devhead_sameinit.separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/'
display_fldr(fldr, inner_key='*')

# %% [markdown]
# ## Mismatched Batchnorm

# %%
large_lr = 'm4m_cache/understand_lowdata/ogbn.small_lr.large.batchdev/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/understand_lowdata/ogbn.small_lr.large.batchdev/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %% [markdown]
# ## Matched Batchnorm

# %% [markdown]
# ### Task-Grouped BatchNorm

# %%
large_lr = 'm4m_cache/understand_lowdata/groupedBN.small_lr.large.batchdev/meta_medium-sized_mammals/0/weight_stats.pkl'
_ = vis_file(large_lr, smooth_factor=1)

print('--'*60)

fldrs = glob('m4m_cache/understand_lowdata/groupedBN.small_lr.large.batchdev/meta_medium-sized_mammals/')
display_fldr(fldrs[0], inner_key='0')

# %% [markdown]
# ## Task Separated Batch Norm

# %%
# large_lr = 'm4m_cache/understand_lowdata/separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/0/weight_stats.pkl'
# _ = vis_file(large_lr, smooth_factor=1)

# print('--'*60)

# fldrs = glob('m4m_cache/understand_lowdata/separateBN.small_lr.large.batchdev/meta_medium-sized_mammals/')
# display_fldr(fldrs[0], inner_key='0')
